# %% [markdown]
# # Income Estimation
#
# ## US Census Demographic Data

# %% [markdown]
# ## 1. Notebook Imports

# %%
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Loading Data

# %%
data=pd.read_csv('acs2017_census_tract_data.csv')
data.head()
# Out:
#       TractId    State          County  TotalPop   Men  Women  Hispanic  \
# 0  1001020100  Alabama  Autauga County      1845   899    946       2.4
# 1  1001020200  Alabama  Autauga County      2172  1167   1005       1.1
# 2  1001020300  Alabama  Autauga County      3385  1533   1852       8.0
# 3  1001020400  Alabama  Autauga County      4267  2001   2266       9.6
# 4  1001020500  Alabama  Autauga County      9965  5054   4911       0.9
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   86.3    5.2     0.0  ...   0.5          0.0         2.1         24.5
# 1   41.6   54.5     0.0  ...   0.0          0.5         0.0         22.2
# 2   61.4   26.5     0.6  ...   1.0          0.8         1.5         23.1
# 3   80.3    7.1     0.5  ...   1.5          2.9         2.1         25.9
# 4   77.5   16.4     0.0  ...   0.8          0.3         0.7         21.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0       881         74.2        21.2           4.5         0.0           4.6
# 1       852         75.9        15.0           9.0         0.0           3.4
# 2      1482         73.3        21.1           4.8         0.7           4.7
# 3      1849         75.8        19.7           4.5         0.0           6.1
# 4      4787         71.4        24.1           4.5         0.0           2.3
#
# [5 rows x 37 columns]

# %% [markdown]
# ## 3. Exploratory Data Analysis and Preprocessing

# %%
data.shape
# Out:
# (74001, 37)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74001 entries, 0 to 74000
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   TractId           74001 non-null  int64
#  1   State             74001 non-null  object
#  2   County            74001 non-null  object
#  3   TotalPop          74001 non-null  int64
#  4   Men               74001 non-null  int64
#  5   Women             74001 non-null  int64
#  6   Hispanic          73305 non-null  float64
#  7   White             73305 non-null  float64
#  8   Black             73305 non-null  float64
#  9   Native            73305 non-null  float64
#  10  Asian             73305 non-null  float64
#  11  Pacific           73305 non-null  float64
#  12  VotingAgeCitizen  74001 non-null  int64
#  13  Income            72885 non-null  float64
#  14  IncomeErr         72885 non-null  float64
#  15  IncomePerCap      73256 non-null  float64
#  16  IncomePerCapErr   73256 non-null  float64
#  17  Poverty           73159 non-null  float64
#  18  ChildPoverty      72891 non-null  float64
#  19  Professional      73190 non-null  float64
#  20  Service           73190 non-null  float64
#  21  Office            73190 non-null  float64
#  22  Construction      73190 non-null  float64
#  23  Production        73190 non-null  float64
#  24  Drive             73200 non-null  float64
#  25  Carpool           73200 non-null  float64
#  26  Transit           73200 non-null  float64
#  27  Walk              73200 non-null  float64
#  28  OtherTransp       73200 non-null  float64
#  29  WorkAtHome        73200 non-null  float64
#  30  MeanCommute       73055 non-null  float64
#  31  Employed          74001 non-null  int64
#  32  PrivateWork       73190 non-null  float64
#  33  PublicWork        73190 non-null  float64
#  34  SelfEmployed      73190 non-null  float64
#  35  FamilyWork        73190 non-null  float64
#  36  Unemployment      73191 non-null  float64
# dtypes: float64(29), int64(6), object(2)
# memory usage: 20.9+ MB

# %%
data.isnull().sum()
# Out:
# TractId                0
# State                  0
# County                 0
# TotalPop               0
# Men                    0
# Women                  0
# Hispanic             696
# White                696
# Black                696
# Native               696
# Asian                696
# Pacific              696
# VotingAgeCitizen       0
# Income              1116
# IncomeErr           1116
# IncomePerCap         745
# IncomePerCapErr      745
# Poverty              842
# ChildPoverty        1110
# Professional         811
# Service              811
# Office               811
# Construction         811
# Production           811
# Drive                801
# Carpool              801
# Transit              801
# Walk                 801
# OtherTransp          801
# WorkAtHome           801
# MeanCommute          946
# Employed               0
# PrivateWork          811
# PublicWork           811
# SelfEmployed         811
# FamilyWork           811
# Unemployment         810
# dtype: int64

# %%
#Let's drop the rows containing NaN
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# TractId             0
# State               0
# County              0
# TotalPop            0
# Men                 0
# Women               0
# Hispanic            0
# White               0
# Black               0
# Native              0
# Asian               0
# Pacific             0
# VotingAgeCitizen    0
# Income              0
# IncomeErr           0
# IncomePerCap        0
# IncomePerCapErr     0
# Poverty             0
# ChildPoverty        0
# Professional        0
# Service             0
# Office              0
# Construction        0
# Production          0
# Drive               0
# Carpool             0
# Transit             0
# Walk                0
# OtherTransp         0
# WorkAtHome          0
# MeanCommute         0
# Employed            0
# PrivateWork         0
# PublicWork          0
# SelfEmployed        0
# FamilyWork          0
# Unemployment        0
# dtype: int64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [TractId, State, County, TotalPop, Men, Women, Hispanic, White, Black, Native, Asian, Pacific, VotingAgeCitizen, Income, IncomeErr, IncomePerCap, IncomePerCapErr, Poverty, ChildPoverty, Professional, Service, Office, Construction, Production, Drive, Carpool, Transit, Walk, OtherTransp, WorkAtHome, MeanCommute, Employed, PrivateWork, PublicWork, SelfEmployed, FamilyWork, Unemployment]
# Index: []
#
# [0 rows x 37 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72718 entries, 0 to 74000
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   TractId           72718 non-null  int64
#  1   State             72718 non-null  object
#  2   County            72718 non-null  object
#  3   TotalPop          72718 non-null  int64
#  4   Men               72718 non-null  int64
#  5   Women             72718 non-null  int64
#  6   Hispanic          72718 non-null  float64
#  7   White             72718 non-null  float64
#  8   Black             72718 non-null  float64
#  9   Native            72718 non-null  float64
#  10  Asian             72718 non-null  float64
#  11  Pacific           72718 non-null  float64
#  12  VotingAgeCitizen  72718 non-null  int64
#  13  Income            72718 non-null  float64
#  14  IncomeErr         72718 non-null  float64
#  15  IncomePerCap      72718 non-null  float64
#  16  IncomePerCapErr   72718 non-null  float64
#  17  Poverty           72718 non-null  float64
#  18  ChildPoverty      72718 non-null  float64
#  19  Professional      72718 non-null  float64
#  20  Service           72718 non-null  float64
#  21  Office            72718 non-null  float64
#  22  Construction      72718 non-null  float64
#  23  Production        72718 non-null  float64
#  24  Drive             72718 non-null  float64
#  25  Carpool           72718 non-null  float64
#  26  Transit           72718 non-null  float64
#  27  Walk              72718 non-null  float64
#  28  OtherTransp       72718 non-null  float64
#  29  WorkAtHome        72718 non-null  float64
#  30  MeanCommute       72718 non-null  float64
#  31  Employed          72718 non-null  int64
#  32  PrivateWork       72718 non-null  float64
#  33  PublicWork        72718 non-null  float64
#  34  SelfEmployed      72718 non-null  float64
#  35  FamilyWork        72718 non-null  float64
#  36  Unemployment      72718 non-null  float64
# dtypes: float64(29), int64(6), object(2)
# memory usage: 21.1+ MB

# %%
data.describe().T
# Out:
#                     count          mean           std           min  \
# TractId           72718.0  2.837292e+10  1.644198e+10  1.001020e+09
# TotalPop          72718.0  4.443485e+03  2.190183e+03  5.800000e+01
# Men               72718.0  2.184363e+03  1.099954e+03  2.600000e+01
# Women             72718.0  2.259122e+03  1.124605e+03  2.700000e+01
# Hispanic          72718.0  1.728295e+01  2.308443e+01  0.000000e+00
# White             72718.0  6.133714e+01  3.062803e+01  0.000000e+00
# Black             72718.0  1.325442e+01  2.158127e+01  0.000000e+00
# Native            72718.0  7.277758e-01  4.505791e+00  0.000000e+00
# Asian             72718.0  4.752459e+00  8.995573e+00  0.000000e+00
# Pacific           72718.0  1.460821e-01  1.015198e+00  0.000000e+00
# VotingAgeCitizen  72718.0  3.141162e+03  1.512610e+03  4.000000e+01
# Income            72718.0  6.112000e+04  3.051106e+04  2.692000e+03
# IncomeErr         72718.0  9.690326e+03  6.119407e+03  7.280000e+02
# IncomePerCap      72718.0  3.066665e+04  1.584413e+04  1.631000e+03
# IncomePerCapErr   72718.0  4.249726e+03  2.991010e+03  3.510000e+02
# Poverty           72718.0  1.604672e+01  1.242864e+01  0.000000e+00
# ChildPoverty      72718.0  2.114848e+01  1.857271e+01  0.000000e+00
# Professional      72718.0  3.555381e+01  1.503879e+01  0.000000e+00
# Service           72718.0  1.884795e+01  7.969609e+00  0.000000e+00
# Office            72718.0  2.341316e+01  5.591354e+00  0.000000e+00
# Construction      72718.0  9.263044e+00  5.943849e+00  0.000000e+00
# Production        72718.0  1.292231e+01  7.592511e+00  0.000000e+00
# Drive             72718.0  7.588083e+01  1.496050e+01  0.000000e+00
# Carpool           72718.0  9.324557e+00  5.107717e+00  0.000000e+00
# Transit           72718.0  5.370585e+00  1.162606e+01  0.000000e+00
# Walk              72718.0  2.925778e+00  5.260623e+00  0.000000e+00
# OtherTransp       72718.0  1.886076e+00  2.485812e+00  0.000000e+00
# WorkAtHome        72718.0  4.612646e+00  3.770733e+00  0.000000e+00
# MeanCommute       72718.0  2.608033e+01  7.095680e+00  4.200000e+00
# Employed          72718.0  2.081309e+03  1.120110e+03  2.000000e+01
# PrivateWork       72718.0  7.951183e+01  7.957350e+00  1.750000e+01
# PublicWork        72718.0  1.414950e+01  7.164790e+00  0.000000e+00
# SelfEmployed      72718.0  6.167661e+00  3.798703e+00  0.000000e+00
# FamilyWork        72718.0  1.712313e-01  4.516299e-01  0.000000e+00
# Unemployment      72718.0  7.224917e+00  5.099419e+00  0.000000e+00
#
#                            25%           50%           75%           max
# TractId           1.304703e+10  2.804700e+10  4.200341e+10  7.215375e+10
# TotalPop          2.958000e+03  4.137000e+03  5.532750e+03  6.552800e+04
# Men               1.440000e+03  2.024000e+03  2.719000e+03  3.226600e+04
# Women             1.494000e+03  2.102000e+03  2.817000e+03  3.326200e+04
# Hispanic          2.600000e+00  7.400000e+00  2.110000e+01  1.000000e+02
# White             3.810000e+01  7.050000e+01  8.770000e+01  1.000000e+02
# Black             8.000000e-01  3.800000e+00  1.450000e+01  1.000000e+02
# Native            0.000000e+00  0.000000e+00  4.000000e-01  9.940000e+01
# Asian             2.000000e-01  1.500000e+00  5.000000e+00  9.140000e+01
# Pacific           0.000000e+00  0.000000e+00  0.000000e+00  7.190000e+01
# VotingAgeCitizen  2.096000e+03  2.926000e+03  3.923000e+03  3.938900e+04
# Income            4.038000e+04  5.441300e+04  7.468800e+04  2.497500e+05
# IncomeErr         5.737000e+03  8.268000e+03  1.190900e+04  1.533650e+05
# IncomePerCap      2.062400e+04  2.724900e+04  3.641300e+04  2.202530e+05
# IncomePerCapErr   2.508000e+03  3.404000e+03  4.959000e+03  8.441400e+04
# Poverty           6.900000e+00  1.260000e+01  2.180000e+01  1.000000e+02
# ChildPoverty      6.200000e+00  1.630000e+01  3.160000e+01  1.000000e+02
# Professional      2.470000e+01  3.330000e+01  4.480000e+01  9.220000e+01
# Service           1.330000e+01  1.770000e+01  2.320000e+01  7.090000e+01
# Office            1.970000e+01  2.320000e+01  2.690000e+01  7.230000e+01
# Construction      5.000000e+00  8.400000e+00  1.250000e+01  6.810000e+01
# Production        7.200000e+00  1.180000e+01  1.750000e+01  6.050000e+01
# Drive             7.240000e+01  7.990000e+01  8.490000e+01  1.000000e+02
# Carpool           5.800000e+00  8.500000e+00  1.190000e+01  6.400000e+01
# Transit           0.000000e+00  1.000000e+00  4.600000e+00  9.080000e+01
# Walk              4.000000e-01  1.400000e+00  3.300000e+00  7.770000e+01
# OtherTransp       4.000000e-01  1.200000e+00  2.500000e+00  5.340000e+01
# WorkAtHome        2.000000e+00  3.800000e+00  6.300000e+00  8.280000e+01
# MeanCommute       2.110000e+01  2.540000e+01  3.030000e+01  7.390000e+01
# Employed          1.306000e+03  1.915000e+03  2.651000e+03  2.894500e+04
# PrivateWork       7.530000e+01  8.060000e+01  8.500000e+01  1.000000e+02
# PublicWork        9.300000e+00  1.300000e+01  1.760000e+01  8.070000e+01
# SelfEmployed      3.500000e+00  5.500000e+00  8.000000e+00  4.740000e+01
# FamilyWork        0.000000e+00  0.000000e+00  0.000000e+00  2.230000e+01
# Unemployment      3.900000e+00  6.000000e+00  9.000000e+00  6.280000e+01

# %%
data.describe(include='O').T
# Out:
#         count unique                 top  freq
# State   72718     52          California  7932
# County  72718   1954  Los Angeles County  2300

# %%
data.describe(percentiles=[.25,.5,.75,.90,.95,.99])
# Out:
#             TractId      TotalPop           Men         Women      Hispanic  \
# count  7.271800e+04  72718.000000  72718.000000  72718.000000  72718.000000
# mean   2.837292e+10   4443.485121   2184.362647   2259.122473     17.282951
# std    1.644198e+10   2190.183318   1099.954423   1124.604806     23.084428
# min    1.001020e+09     58.000000     26.000000     27.000000      0.000000
# 25%    1.304703e+10   2958.000000   1440.000000   1494.000000      2.600000
# 50%    2.804700e+10   4137.000000   2024.000000   2102.000000      7.400000
# 75%    4.200341e+10   5532.750000   2719.000000   2817.000000     21.100000
# 90%    4.845795e+10   7023.000000   3485.000000   3589.000000     52.200000
# 95%    5.303303e+10   8070.000000   4021.150000   4119.000000     74.400000
# 99%    7.202103e+10  11280.000000   5651.830000   5778.660000     98.800000
# max    7.215375e+10  65528.000000  32266.000000  33262.000000    100.000000
#
#               White         Black        Native         Asian       Pacific  \
# count  72718.000000  72718.000000  72718.000000  72718.000000  72718.000000
# mean      61.337143     13.254417      0.727776      4.752459      0.146082
# std       30.628031     21.581269      4.505791      8.995573      1.015198
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       38.100000      0.800000      0.000000      0.200000      0.000000
# 50%       70.500000      3.800000      0.000000      1.500000      0.000000
# 75%       87.700000     14.500000      0.400000      5.000000      0.000000
# 90%       94.700000     41.800000      1.200000     12.600000      0.200000
# 95%       96.600000     69.100000      2.200000     21.200000      0.600000
# 99%       98.600000     94.400000     10.600000     47.700000      3.100000
# max      100.000000    100.000000     99.400000     91.400000     71.900000
#
#        ...          Walk   OtherTransp    WorkAtHome   MeanCommute  \
# count  ...  72718.000000  72718.000000  72718.000000  72718.000000
# mean   ...      2.925778      1.886076      4.612646     26.080334
# std    ...      5.260623      2.485812      3.770733      7.095680
# min    ...      0.000000      0.000000      0.000000      4.200000
# 25%    ...      0.400000      0.400000      2.000000     21.100000
# 50%    ...      1.400000      1.200000      3.800000     25.400000
# 75%    ...      3.300000      2.500000      6.300000     30.300000
# 90%    ...      6.800000      4.500000      9.300000     35.300000
# 95%    ...     10.700000      6.300000     11.500000     38.800000
# 99%    ...     27.800000     11.600000     17.200000     46.400000
# max    ...     77.700000     53.400000     82.800000     73.900000
#
#            Employed   PrivateWork    PublicWork  SelfEmployed    FamilyWork  \
# count  72718.000000  72718.000000  72718.000000  72718.000000  72718.000000
# mean    2081.309139     79.511827     14.149495      6.167661      0.171231
# std     1120.109805      7.957350      7.164790      3.798703      0.451630
# min       20.000000     17.500000      0.000000      0.000000      0.000000
# 25%     1306.000000     75.300000      9.300000      3.500000      0.000000
# 50%     1915.000000     80.600000     13.000000      5.500000      0.000000
# 75%     2651.000000     85.000000     17.600000      8.000000      0.000000
# 90%     3436.000000     88.400000     23.000000     11.000000      0.600000
# 95%     3995.000000     90.300000     27.000000     13.200000      1.000000
# 99%     5483.830000     93.600000     37.400000     18.800000      2.000000
# max    28945.000000    100.000000     80.700000     47.400000     22.300000
#
#        Unemployment
# count  72718.000000
# mean       7.224917
# std        5.099419
# min        0.000000
# 25%        3.900000
# 50%        6.000000
# 75%        9.000000
# 90%       13.300000
# 95%       16.900000
# 99%       26.500000
# max       62.800000
#
# [11 rows x 35 columns]

# %%
#Let's delete first 3 column, unnecessary for our analysis, we also can drop the IncomeErr, IncomePerCap and IncomePerCapErr columns.
data_new= data.drop(['TractId', 'State', 'County','IncomeErr','IncomePerCap','IncomePerCapErr'], axis=1)
data_new.head()
# Out:
#    TotalPop   Men  Women  Hispanic  White  Black  Native  Asian  Pacific  \
# 0      1845   899    946       2.4   86.3    5.2     0.0    1.2      0.0
# 1      2172  1167   1005       1.1   41.6   54.5     0.0    1.0      0.0
# 2      3385  1533   1852       8.0   61.4   26.5     0.6    0.7      0.4
# 3      4267  2001   2266       9.6   80.3    7.1     0.5    0.2      0.0
# 4      9965  5054   4911       0.9   77.5   16.4     0.0    3.1      0.0
#
#    VotingAgeCitizen  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0              1407  ...   0.5          0.0         2.1         24.5
# 1              1652  ...   0.0          0.5         0.0         22.2
# 2              2480  ...   1.0          0.8         1.5         23.1
# 3              3257  ...   1.5          2.9         2.1         25.9
# 4              7229  ...   0.8          0.3         0.7         21.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0       881         74.2        21.2           4.5         0.0           4.6
# 1       852         75.9        15.0           9.0         0.0           3.4
# 2      1482         73.3        21.1           4.8         0.7           4.7
# 3      1849         75.8        19.7           4.5         0.0           6.1
# 4      4787         71.4        24.1           4.5         0.0           2.3
#
# [5 rows x 31 columns]

# %%
#Generally, population metrics are in % of the population, 
#but these metrics are total values.

data[["TotalPop","Men","Women","VotingAgeCitizen","Employed"]].describe()
# Out:
#            TotalPop           Men         Women  VotingAgeCitizen  \
# count  72718.000000  72718.000000  72718.000000      72718.000000
# mean    4443.485121   2184.362647   2259.122473       3141.161982
# std     2190.183318   1099.954423   1124.604806       1512.610257
# min       58.000000     26.000000     27.000000         40.000000
# 25%     2958.000000   1440.000000   1494.000000       2096.000000
# 50%     4137.000000   2024.000000   2102.000000       2926.000000
# 75%     5532.750000   2719.000000   2817.000000       3923.000000
# max    65528.000000  32266.000000  33262.000000      39389.000000
#
#            Employed
# count  72718.000000
# mean    2081.309139
# std     1120.109805
# min       20.000000
# 25%     1306.000000
# 50%     1915.000000
# 75%     2651.000000
# max    28945.000000

# %% [markdown]
# TotalPop always is the sum of Men and Women population, let's drop it:

# %%
data_new= data_new.drop(['TotalPop'], axis=1)
data_new.head()
# Out:
#     Men  Women  Hispanic  White  Black  Native  Asian  Pacific  \
# 0   899    946       2.4   86.3    5.2     0.0    1.2      0.0
# 1  1167   1005       1.1   41.6   54.5     0.0    1.0      0.0
# 2  1533   1852       8.0   61.4   26.5     0.6    0.7      0.4
# 3  2001   2266       9.6   80.3    7.1     0.5    0.2      0.0
# 4  5054   4911       0.9   77.5   16.4     0.0    3.1      0.0
#
#    VotingAgeCitizen   Income  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0              1407  67826.0  ...   0.5          0.0         2.1         24.5
# 1              1652  41287.0  ...   0.0          0.5         0.0         22.2
# 2              2480  46806.0  ...   1.0          0.8         1.5         23.1
# 3              3257  55895.0  ...   1.5          2.9         2.1         25.9
# 4              7229  68143.0  ...   0.8          0.3         0.7         21.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0       881         74.2        21.2           4.5         0.0           4.6
# 1       852         75.9        15.0           9.0         0.0           3.4
# 2      1482         73.3        21.1           4.8         0.7           4.7
# 3      1849         75.8        19.7           4.5         0.0           6.1
# 4      4787         71.4        24.1           4.5         0.0           2.3
#
# [5 rows x 30 columns]

# %%
# Converting "Men","Women","VotingAgeCitizen","Employed" columns to % of Total Population
convert = ['Men','Women','VotingAgeCitizen','Employed']
data_new[convert] = data_new[convert].div(data["TotalPop"], axis="index")*100

# %%
#The percentage of Native, Asian, and Pacific races is generally very low. so let's assign this three features to a feature.
data_new['RaceOther']= data_new['Asian'] + data_new['Pacific']+ data_new['Native']
data_new=data_new.drop(['Asian', 'Pacific','Native'], axis=1)

# %%
# to calculate some metrics, Filter out data where Income is > 0 in the dataset
data_new = data_new.loc[data_new['Income'] > 0]

# %%
data_new.head()
# Out:
#          Men      Women  Hispanic  White  Black  VotingAgeCitizen   Income  \
# 0  48.726287  51.273713       2.4   86.3    5.2         76.260163  67826.0
# 1  53.729282  46.270718       1.1   41.6   54.5         76.058932  41287.0
# 2  45.288035  54.711965       8.0   61.4   26.5         73.264402  46806.0
# 3  46.894774  53.105226       9.6   80.3    7.1         76.329974  55895.0
# 4  50.717511  49.282489       0.9   77.5   16.4         72.543904  68143.0
#
#    Poverty  ChildPoverty  Professional  ...  OtherTransp  WorkAtHome  \
# 0     10.7          20.8          38.5  ...          0.0         2.1
# 1     22.4          35.8          30.5  ...          0.5         0.0
# 2     14.7          21.1          27.9  ...          0.8         1.5
# 3      2.3           1.7          29.0  ...          2.9         2.1
# 4     12.2          17.9          48.8  ...          0.3         0.7
#
#    MeanCommute   Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  \
# 0         24.5  47.750678         74.2        21.2           4.5         0.0
# 1         22.2  39.226519         75.9        15.0           9.0         0.0
# 2         23.1  43.781388         73.3        21.1           4.8         0.7
# 3         25.9  43.332552         75.8        19.7           4.5         0.0
# 4         21.0  48.038133         71.4        24.1           4.5         0.0
#
#    Unemployment  RaceOther
# 0           4.6        1.2
# 1           3.4        1.0
# 2           4.7        1.7
# 3           6.1        0.7
# 4           2.3        3.1
#
# [5 rows x 28 columns]

# %%
#to move the target column to the last
cols = list(data_new.columns.values)
cols.pop(cols.index('Income')) 
data_new = data_new[cols+['Income']]
data_new.head()
# Out:
#          Men      Women  Hispanic  White  Black  VotingAgeCitizen  Poverty  \
# 0  48.726287  51.273713       2.4   86.3    5.2         76.260163     10.7
# 1  53.729282  46.270718       1.1   41.6   54.5         76.058932     22.4
# 2  45.288035  54.711965       8.0   61.4   26.5         73.264402     14.7
# 3  46.894774  53.105226       9.6   80.3    7.1         76.329974      2.3
# 4  50.717511  49.282489       0.9   77.5   16.4         72.543904     12.2
#
#    ChildPoverty  Professional  Service  ...  WorkAtHome  MeanCommute  \
# 0          20.8          38.5     15.6  ...         2.1         24.5
# 1          35.8          30.5     24.9  ...         0.0         22.2
# 2          21.1          27.9     19.4  ...         1.5         23.1
# 3           1.7          29.0     16.6  ...         2.1         25.9
# 4          17.9          48.8     13.8  ...         0.7         21.0
#
#     Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment  \
# 0  47.750678         74.2        21.2           4.5         0.0           4.6
# 1  39.226519         75.9        15.0           9.0         0.0           3.4
# 2  43.781388         73.3        21.1           4.8         0.7           4.7
# 3  43.332552         75.8        19.7           4.5         0.0           6.1
# 4  48.038133         71.4        24.1           4.5         0.0           2.3
#
#    RaceOther   Income
# 0        1.2  67826.0
# 1        1.0  41287.0
# 2        1.7  46806.0
# 3        0.7  55895.0
# 4        3.1  68143.0
#
# [5 rows x 28 columns]

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72718 entries, 0 to 74000
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Men               72718 non-null  float64
#  1   Women             72718 non-null  float64
#  2   Hispanic          72718 non-null  float64
#  3   White             72718 non-null  float64
#  4   Black             72718 non-null  float64
#  5   VotingAgeCitizen  72718 non-null  float64
#  6   Poverty           72718 non-null  float64
#  7   ChildPoverty      72718 non-null  float64
#  8   Professional      72718 non-null  float64
#  9   Service           72718 non-null  float64
#  10  Office            72718 non-null  float64
#  11  Construction      72718 non-null  float64
#  12  Production        72718 non-null  float64
#  13  Drive             72718 non-null  float64
#  14  Carpool           72718 non-null  float64
#  15  Transit           72718 non-null  float64
#  16  Walk              72718 non-null  float64
#  17  OtherTransp       72718 non-null  float64
#  18  WorkAtHome        72718 non-null  float64
#  19  MeanCommute       72718 non-null  float64
#  20  Employed          72718 non-null  float64
#  21  PrivateWork       72718 non-null  float64
#  22  PublicWork        72718 non-null  float64
#  23  SelfEmployed      72718 non-null  float64
#  24  FamilyWork        72718 non-null  float64
#  25  Unemployment      72718 non-null  float64
#  26  RaceOther         72718 non-null  float64
#  27  Income            72718 non-null  float64
# dtypes: float64(28)
# memory usage: 16.1 MB

# %%
Categorical=data.select_dtypes(include='object').columns.tolist()
Categorical
# Out:
# ['State', 'County']

# %%
Numerical=data_new.select_dtypes(exclude='object').columns.tolist()
Numerical
# Out:
# ['Men',
#  'Women',
#  'Hispanic',
#  'White',
#  'Black',
#  'VotingAgeCitizen',
#  'Poverty',
#  'ChildPoverty',
#  'Professional',
#  'Service',
#  'Office',
#  'Construction',
#  'Production',
#  'Drive',
#  'Carpool',
#  'Transit',
#  'Walk',
#  'OtherTransp',
#  'WorkAtHome',
#  'MeanCommute',
#  'Employed',
#  'PrivateWork',
#  'PublicWork',
#  'SelfEmployed',
#  'FamilyWork',
#  'Unemployment',
#  'RaceOther',
#  'Income']

# %% [markdown]
# ### Some views of the Dataset

# %%
fig, ax = plt.subplots(1, 1, figsize = (15, 10))
plt.suptitle('Count plot for State column', fontsize = 30, color= 'teal')
ax= sns.countplot(x=data["State"], palette= 'viridis')
ax.set(xlabel = "State")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.tight_layout()
plt.show()

# %%
income_state= data.groupby(['State'],as_index=False)['Income'].mean().sort_values("Income", ascending = False)
income_state
# Out:
#                    State        Income
# 8   District of Columbia  83202.653409
# 20              Maryland  83046.715843
# 30            New Jersey  81297.738516
# 6            Connecticut  79622.418919
# 11                Hawaii  79511.065147
# 21         Massachusetts  78684.783058
# 47              Virginia  76522.147929
# 1                 Alaska  73796.757576
# 29         New Hampshire  73360.291096
# 4             California  73126.602496
# 48            Washington  69931.753643
# 5               Colorado  69643.886179
# 45                  Utah  68476.230241
# 32              New York  68467.905400
# 23             Minnesota  67166.057851
# 7               Delaware  64532.525822
# 13              Illinois  63387.933977
# 40          Rhode Island  63071.820833
# 34          North Dakota  61822.809756
# 51               Wyoming  60757.900763
# 44                 Texas  59591.670387
# 38          Pennsylvania  59538.752993
# 37                Oregon  59490.194175
# 27              Nebraska  59265.554080
# 28                Nevada  58872.962798
# 46               Vermont  58240.409836
# 2                Arizona  57943.061321
# 50             Wisconsin  57278.612880
# 16                Kansas  56795.245059
# 15                  Iowa  56246.124088
# 22              Michigan  54840.419296
# 42          South Dakota  54839.783784
# 10               Georgia  54680.631282
# 9                Florida  54284.379612
# 33        North Carolina  53323.972673
# 25              Missouri  53099.645231
# 35                  Ohio  53043.526783
# 19                 Maine  52807.076923
# 14               Indiana  51887.099466
# 12                 Idaho  51426.734007
# 26               Montana  51216.347015
# 36              Oklahoma  50663.818882
# 43             Tennessee  50491.377808
# 41        South Carolina  49375.685476
# 31            New Mexico  48941.945783
# 17              Kentucky  47975.172257
# 18             Louisiana  46892.042819
# 0                Alabama  45955.352941
# 3               Arkansas  44245.267936
# 49         West Virginia  44055.517598
# 24           Mississippi  41510.481651
# 39           Puerto Rico  21206.667429

# %%
income_state= data.groupby(['State'],as_index=False)['Income'].mean()

fig, ax = plt.subplots(figsize=(15, 6))
plt.suptitle('Average income of states', fontsize = 30, color= 'teal')
ax = sns.barplot(x=income_state['State'].values, y=income_state['Income'].values)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %%
sns.set_context('poster', font_scale= 0.6)
fig, ax  = plt.subplots(len(Numerical), 1, figsize=(20, 6))

plt.suptitle('Histograms of all Numerical Features', fontsize = 20)

for i in Numerical:
    ax=sns.histplot(x= data_new[i], color='teal', bins= 15, kde= True, palette= 'twilight')
    ax.set(xlabel= i , ylabel= 'Frequency')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# let's look at the correlations before we build the models:

# %%
plt.figure(figsize=(25, 15))
plt.suptitle('Correlations', fontsize = 30, color= 'teal')
corr = data_new.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
for i in data_new.columns:
    cor_x=data_new[i]
    cor_y=data_new['Income']
    print(i,":", cor_x.corr(cor_y)*100)
# Out:
# Men : 5.122724443383671
# Women : -5.122724443383669
# Hispanic : -22.321616775351995
# White : 30.436711279202637
# Black : -31.313432952037484
# VotingAgeCitizen : 7.515923048839424
# Poverty : -69.54192381625678
# ChildPoverty : -64.95426501516917
# Professional : 73.71190997598546
# Service : -58.583377789205485
# Office : -9.804291116125583
# Construction : -33.93563024260502
# Production : -50.72344516619584
# Drive : 4.415357440852722
# Carpool : -28.141383268545283
# Transit : 1.4167496041355756
# Walk : -13.264187155264423
# OtherTransp : -8.562624642943724
# WorkAtHome : 40.369847664168134
# MeanCommute : 24.329040724060416
# Employed : 44.5001383246484
# PrivateWork : -3.585605639115847
# PublicWork : -0.46839750695334953
# SelfEmployed : 8.310958779972735
# FamilyWork : 0.7076658123181466
# Unemployment : -45.762759454355894
# RaceOther : 23.67092864299628
# Income : 99.99999999999999

# %%
correlations=data_new.corr()['Income'][:-1].abs()
fig, ax = plt.subplots(figsize=(15, 6))
plt.suptitle('Correlations', fontsize = 30, color= 'teal')
ax = sns.barplot(x=correlations.index.values, y=correlations.values)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %% [markdown]
# ### Handling Outliers

# %%
for i in Numerical:
    plt.figure()
    plt.tight_layout()
    
    plt.gca().set(xlabel= i,ylabel='Frequency')
    plt.boxplot(data_new[i])

# %%
number_of_outliers=[None]*len(Numerical)
q75=[None]*len(Numerical)
q25=[None]*len(Numerical)
IQR=[None]*len(Numerical)
unique_values=[None]*len(Numerical)
ratio=[None]*len(Numerical)

for i, p in enumerate(Numerical):
    q75[i], q25[i]= np.percentile(data_new[p],[95,5])
    IQR[i]= q75[i]- q25[i]
    #number_of_outliers[i]=df[~((df[p] < (q75[i] + 1.5 * IQR[i])) & (df[p] > (q25[i]-1.5*IQR[i])))].shape[0]
    number_of_outliers[i]=len((np.where((data_new[p] > (q75[i] + 1.5 * IQR[i])) | (data_new[p]< (q25[i] - 1.5 * IQR[i])))[0]))
    unique_values[i]= len(data_new[p].unique())
    ratio[i]= number_of_outliers[i]/unique_values[i]
    print('outliers of',p," =", number_of_outliers[i])
    print('unique_values',p," =", unique_values[i])
    print('ratio',p," =", ratio[i])
    print("*"*40)
# Out:
# outliers of Men  = 161
# unique_values Men  = 68150
# ratio Men  = 0.0023624358033749082
# ****************************************
# outliers of Women  = 161
# unique_values Women  = 68150
# ratio Women  = 0.0023624358033749082
# ****************************************
# outliers of Hispanic  = 0
# unique_values Hispanic  = 1001
# ratio Hispanic  = 0.0
# ****************************************
# outliers of White  = 0
# unique_values White  = 1001
# ratio White  = 0.0
# ****************************************
# outliers of Black  = 0
# unique_values Black  = 1001
# ratio Black  = 0.0
# ****************************************
# outliers of VotingAgeCitizen  = 0
# unique_values VotingAgeCitizen  = 70408
# ratio VotingAgeCitizen  = 0.0
# ****************************************
# outliers of Poverty  = 2
# unique_values Poverty  = 796
# ratio Poverty  = 0.002512562814070352
# ****************************************
# outliers of ChildPoverty  = 0
# unique_values ChildPoverty  = 954
# ratio ChildPoverty  = 0.0
# ****************************************
# outliers of Professional  = 0
# unique_values Professional  = 865
# ratio Professional  = 0.0
# ****************************************
# outliers of Service  = 0
# unique_values Service  = 579
# ratio Service  = 0.0
# ****************************************
# outliers of Office  = 2
# unique_values Office  = 480
# ratio Office  = 0.004166666666666667
# ****************************************
# outliers of Construction  = 48
# unique_values Construction  = 483
# ratio Construction  = 0.09937888198757763
# ****************************************
# outliers of Production  = 0
# unique_values Production  = 503
# ratio Production  = 0.0
# ****************************************
# outliers of Drive  = 0
# unique_values Drive  = 981
# ratio Drive  = 0.0
# ****************************************
# outliers of Carpool  = 19
# unique_values Carpool  = 407
# ratio Carpool  = 0.04668304668304668
# ****************************************
# outliers of Transit  = 349
# unique_values Transit  = 831
# ratio Transit  = 0.41997593261131166
# ****************************************
# outliers of Walk  = 779
# unique_values Walk  = 556
# ratio Walk  = 1.4010791366906474
# ****************************************
# outliers of OtherTransp  = 265
# unique_values OtherTransp  = 283
# ratio OtherTransp  = 0.9363957597173145
# ****************************************
# outliers of WorkAtHome  = 83
# unique_values WorkAtHome  = 335
# ratio WorkAtHome  = 0.24776119402985075
# ****************************************
# outliers of MeanCommute  = 1
# unique_values MeanCommute  = 526
# ratio MeanCommute  = 0.0019011406844106464
# ****************************************
# outliers of Employed  = 0
# unique_values Employed  = 70564
# ratio Employed  = 0.0
# ****************************************
# outliers of PrivateWork  = 24
# unique_values PrivateWork  = 673
# ratio PrivateWork  = 0.03566121842496285
# ****************************************
# outliers of PublicWork  = 68
# unique_values PublicWork  = 621
# ratio PublicWork  = 0.10950080515297907
# ****************************************
# outliers of SelfEmployed  = 33
# unique_values SelfEmployed  = 318
# ratio SelfEmployed  = 0.10377358490566038
# ****************************************
# outliers of FamilyWork  = 381
# unique_values FamilyWork  = 73
# ratio FamilyWork  = 5.219178082191781
# ****************************************
# outliers of Unemployment  = 86
# unique_values Unemployment  = 447
# ratio Unemployment  = 0.19239373601789708
# ****************************************
# outliers of RaceOther  = 602
# unique_values RaceOther  = 1424
# ratio RaceOther  = 0.42275280898876405
# ****************************************
# outliers of Income  = 0
# unique_values Income  = 41774
# ratio Income  = 0.0
# ****************************************

# %%
#Find the outliers records which fall with +/- 5% boundaries 

Q1 = data_new.quantile(0.05)
Q3 = data_new.quantile(0.95)
IQR = Q3 - Q1

print("Number of outliers for entire dataset = ", len(data_new[((data_new < (Q1 - 1.5 * IQR)) |(data_new > (Q3 + 1.5 * IQR))).any(axis=1)]))
# Out:
# Number of outliers for entire dataset =  2682

# %% [markdown]
# It is inevitable to have outliers in the data set. Dropping outliers can make the model less reliable. So, I decided that I will keep them in the dataset.

# %% [markdown]
# ### Splitting the data into train and test sets

# %%
X= data_new.drop(["Income"], axis=1)
y= data_new.Income

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((54538, 27), (18180, 27), (54538,), (18180,))

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.decomposition import PCA

# %%
pca = PCA()

# %%
pipe = Pipeline(steps=[
             ("scaler", StandardScaler()),
             ("imputer", SimpleImputer()),
             ("pca", pca)])

# %%
pipe.fit_transform(X_train)
pipe.transform(X_test)
# Out:
# array([[-2.05514987e+00,  6.08439017e+00,  1.18150843e+00, ...,
#          4.61772726e-03, -8.19169296e-04,  1.71326944e-17],
#        [ 1.96236761e+00, -9.91652677e-01,  1.18553052e+00, ...,
#          1.15376856e-04,  1.05964533e-04, -1.63584419e-16],
#        [ 1.68312775e+00, -1.65866396e+00,  1.19847681e+00, ...,
#          1.13398433e-03,  4.83360757e-03, -4.28861578e-16],
#        ...,
#        [-2.83552440e+00,  1.16397858e+00, -1.25574286e+00, ...,
#          1.38941162e-05,  2.85183249e-05, -7.81686716e-16],
#        [-7.50600122e-01, -1.53811640e+00,  1.31369106e+00, ...,
#          1.19978768e-04,  1.49009956e-04, -3.81398508e-17],
#        [ 1.15261716e-01, -2.70024010e+00,  3.07025397e-01, ...,
#         -3.56314666e-03,  5.74515208e-03, -8.34756798e-17]])

# %% [markdown]
# ### Using PCA

# %%
pca.n_components_
# Out:
# 27

# %%
pca.explained_variance_
# Out:
# array([5.65165775e+00, 3.07901449e+00, 2.46503214e+00, 2.26318723e+00,
#        1.74603471e+00, 1.45751151e+00, 1.23874885e+00, 1.10778938e+00,
#        9.64445777e-01, 9.35496818e-01, 8.33263275e-01, 7.67572750e-01,
#        7.32229548e-01, 6.62768639e-01, 5.69841908e-01, 5.10021069e-01,
#        4.97776077e-01, 4.37086440e-01, 3.70390780e-01, 3.39192445e-01,
#        2.79135636e-01, 8.93935252e-02, 2.86343091e-03, 2.06105973e-05,
#        1.03111848e-05, 9.97892122e-06, 4.59716895e-31])

# %%
pca.explained_variance_ratio_
# Out:
# array([2.09316820e-01, 1.14035483e-01, 9.12958126e-02, 8.38202124e-02,
#        6.46667664e-02, 5.39809180e-02, 4.58787457e-02, 4.10284840e-02,
#        3.57195590e-02, 3.46473950e-02, 3.08610369e-02, 2.84280991e-02,
#        2.71191156e-02, 2.45465365e-02, 2.11048689e-02, 1.88893229e-02,
#        1.84358129e-02, 1.61880898e-02, 1.37179255e-02, 1.25624528e-02,
#        1.03381673e-02, 3.31081059e-03, 1.06051052e-04, 7.63341459e-07,
#        3.81888731e-07, 3.69582898e-07, 1.70262395e-32])

# %%
# Cumulative explained variance
cum_var_exp = np.cumsum(pca.explained_variance_ratio_*100)
cum_var_exp
# Out:
# array([ 20.93168195,  32.33523022,  41.46481148,  49.84683271,
#         56.31350936,  61.71160116,  66.29947572,  70.40232412,
#         73.97428002,  77.43901952,  80.52512321,  83.36793312,
#         86.07984469,  88.53449834,  90.64498523,  92.53391751,
#         94.37749881,  95.99630779,  97.36810034,  98.62434562,
#         99.65816235,  99.98924341,  99.99984852,  99.99992485,
#         99.99996304, 100.        , 100.        ])

# %%
### PLOT OUT THE EXPLAINED VARIANCES SUPERIMPOSED 
plt.figure(figsize=(10, 5))
plt.plot(cum_var_exp, label='cumulative explained variance')
plt.title('Cumulative Explained Variance as a Function of the Number of Components')
plt.ylabel('%Cumulative Explained variance')
plt.xlabel('Principal components')
plt.axhline(y = 95, color='k', linestyle='--', label = '95% Explained Variance')
plt.axhline(y = 90, color='c', linestyle='--', label = '90% Explained Variance')
plt.axhline(y = 85, color='r', linestyle='--', label = '85% Explained Variance')
plt.legend(loc='best')
plt.show()

# %%
plt.semilogy(pca.explained_variance_ratio_)
plt.xlabel("component_index");

# %%
plt.plot(pca.explained_variance_ratio_)
plt.xlabel("component_index");

# %% [markdown]
# We decided to choose a minimum number of principal components so that 95% of the variance is retained.

# %%
pca95 = PCA(.95)

# %%
pipe95 = Pipeline(steps=[
             ("scaler", StandardScaler()),
             ("imputer", SimpleImputer()),
             ("pca", pca95)])

# %%
X_train= pipe95.fit_transform(X_train)
X_test= pipe95.transform(X_test)

# %%
pca95.n_components_
# Out:
# 18

# %% [markdown]
# In this case, 95% of the variance amounts to 18 principal components.

# %% [markdown]
# ## 4. Modelling

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Models

# %%
models = [
    LinearRegression(),
    Lasso(),
    Ridge(),
    KNeighborsRegressor(),
    DecisionTreeRegressor(),
    RandomForestRegressor(),
]

# %%
from sklearn.metrics import explained_variance_score,mean_absolute_error,r2_score

# %%
for model in models:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)    
    print(model)
    print("\tExplained variance:", explained_variance_score(y_test, y_pred))
    print("\tMean absolute error:", mean_absolute_error(y_test, y_pred))
    print("\tR2 score:", r2_score(y_test, y_pred))
    print()
# Out:
# LinearRegression()
# 	Explained variance: 0.713757208442229
# 	Mean absolute error: 11517.852289109082
# 	R2 score: 0.7137408954237887
#
# Lasso()
# 	Explained variance: 0.7137600158377355
# 	Mean absolute error: 11517.568743886763
# 	R2 score: 0.713743704228001
#
# Ridge()
# 	Explained variance: 0.7137572851522926
# 	Mean absolute error: 11517.834046220487
# 	R2 score: 0.713740972208604
#
# KNeighborsRegressor()
# 	Explained variance: 0.795002424063204
# 	Mean absolute error: 9639.948811881188
# 	R2 score: 0.7916647345762924
#
# DecisionTreeRegressor()
# 	Explained variance: 0.589971110082782
# 	Mean absolute error: 13192.698349834984
# 	R2 score: 0.5898356283061312
#
# RandomForestRegressor()
# 	Explained variance: 0.8162015345628193
# 	Mean absolute error: 8961.267292079208
# 	R2 score: 0.8159879419144964

# %% [markdown]
# The best R^2 estimate we got is from RandomForestRegressor. The estimation value is 0.8160.

# %% [markdown]
# ### Cross Validation for Random Forest model

# %%
from sklearn.model_selection import cross_val_score

# %%
models[5]

# %%
# %%time
np.mean(cross_val_score(models[5], X_train, y_train, cv=10))

# %% [markdown]
# ### GridSearchCV for Random Forest model

# %%
from sklearn.model_selection import GridSearchCV

# %%
# %%time
RF_param_grid = { 
    'n_estimators': [100, 200, 300],
    'max_features': ['auto','log2'],
    'max_depth' : [5,15]}
RF_GridCV = GridSearchCV(models[5], RF_param_grid, cv=5, n_jobs= -1)
RF_GridCV.fit(X_train,y_train)  
print(RF_GridCV.best_params_)    
print(RF_GridCV.best_score_)

# %%
results_RF= pd.DataFrame(RF_GridCV.cv_results_)
results_RF

# %%
RFmodelsample=RandomForestRegressor(n_estimators=500, max_depth=20)

# %%
RFmodelsample.fit(X_train, y_train)

# %%
print(RFmodelsample.score(X_train,y_train))
print(RFmodelsample.score(X_test,y_test))

# %% [markdown]
# ### Polynomial Features

# %% [markdown]
# let's try to apply poly of degree 2:

# %%
from sklearn.preprocessing import PolynomialFeatures

pol= PolynomialFeatures(degree= 2)

# %%
X_train= pol.fit_transform(X_train)
X_test= pol.transform(X_test)

# %%
for model in models:
    model.fit(X_train, y_train)
    train_time = time() - start
    y_pred = model.predict(X_test)   
    print(model)
    print("\tExplained variance:", explained_variance_score(y_test, y_pred))
    print("\tMean absolute error:", mean_absolute_error(y_test, y_pred))
    print("\tR2 score:", r2_score(y_test, y_pred))
    print()

# %% [markdown]
# Significant enhancement for linear, ridge, and lasso. R^2= 0.7137 ----> 0.8061
# There are no good enhancements for other models.

# %% [markdown]
# ## Conclusion
#
# The best R^2 we get is 0.8160 which is very good estimation for Income. The model is Random Forest.

# %%
RF_predictions = models[5].predict(X_test)

RF_errors = abs(RF_predictions - y_test)
RF_mape = np.mean(100 * (RF_errors / y_test))
print('Mean Absolute Percentage Error:', RF_mape)

# %% [markdown]
# A MAPE score of 15% indicates a "good" estimation.

# %%
plt.figure()
ax1 = sns.distplot(y_test, hist=False, color="r", label="Actual Value")
sns.distplot(RF_predictions, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values')
plt.xlabel('Income')

plt.show()
plt.close()
